# %% [markdown]
# <a href="https://colab.research.google.com/github/varshini21604/Market-Basket-Analysis/blob/main/MarketBasketAnalysisPhase5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6153ff05-258a-4467-80f0-dd2a25b0b001" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6153ff05-258a-4467-80f0-dd2a25b0b001">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
# Load the dataset with the correct delimiter
data = pd.read_csv('Assignment_1_data.csv', sep=';')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
data.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    BillNo                             Itemname  Quantity              Date  \
# 0  536365   WHITE HANGING HEART T-LIGHT HOLDER         6  01.12.2010 08:26
# 1  536365                  WHITE METAL LANTERN         6  01.12.2010 08:26
# 2  536365       CREAM CUPID HEARTS COAT HANGER         8  01.12.2010 08:26
# 3  536365  KNITTED UNION FLAG HOT WATER BOTTLE         6  01.12.2010 08:26
# 4  536365       RED WOOLLY HOTTIE WHITE HEART.         6  01.12.2010 08:26
#
#   Price  CustomerID        Country,
# 0  2,55       17850  United Kingdom
# 1  3,39       17850  United Kingdom
# 2  2,75       17850  United Kingdom
# ...

# %%
data.fillna(0,inplace=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
data.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    BillNo                             Itemname  Quantity              Date  \
# 0  536365   WHITE HANGING HEART T-LIGHT HOLDER         6  01.12.2010 08:26
# 1  536365                  WHITE METAL LANTERN         6  01.12.2010 08:26
# 2  536365       CREAM CUPID HEARTS COAT HANGER         8  01.12.2010 08:26
# 3  536365  KNITTED UNION FLAG HOT WATER BOTTLE         6  01.12.2010 08:26
# 4  536365       RED WOOLLY HOTTIE WHITE HEART.         6  01.12.2010 08:26
#
#   Price  CustomerID        Country,
# 0  2,55       17850  United Kingdom
# 1  3,39       17850  United Kingdom
# 2  2,75       17850  United Kingdom
# ...

# %%
transactions = []
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
basket = pd.pivot_table(data,index='BillNo',columns='Itemname',values='Quantity', \
                        aggfunc='sum',fill_value=0)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
basket.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Itemname  ASSORTED COLOUR BIRD ORNAMENT  BOX OF 6 ASSORTED COLOUR TEASPOONS  \
# BillNo
# 536365                                0                                   0
# 536366                                0                                   0
# 536367                               32                                   6
# 536368                                0                                   0
#
# Itemname  BOX OF VINTAGE ALPHABET BLOCKS  BOX OF VINTAGE JIGSAW BLOCKS  \
# BillNo
# 536365                                 0                             0
# 536366                                 0                             0
# ...

# %%
def convert_into_binary(x):
    if x > 0:
        return 1
    else:
        return 0
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
basket_sets = basket.applymap(convert_into_binary)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
frequent_itemsets = apriori(basket_sets, min_support=0.07, use_colnames=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/mlxtend/frequent_patterns/fpcommon.py:110: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(

# %%
frequent_itemsets
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#       support                                           itemsets
# 0        0.25                    (ASSORTED COLOUR BIRD ORNAMENT)
# 1        0.25               (BOX OF 6 ASSORTED COLOUR TEASPOONS)
# 2        0.25                   (BOX OF VINTAGE ALPHABET BLOCKS)
# 3        0.25                     (BOX OF VINTAGE JIGSAW BLOCKS)
# 4        0.25                   (CREAM CUPID HEARTS COAT HANGER)
# ...       ...                                                ...
# 4223     0.25  (RECIPE BOX WITH METAL HEART, DOORMAT NEW ENGL...
# 4224     0.25  (BOX OF VINTAGE JIGSAW BLOCKS, RECIPE BOX WITH...
# ...

# %%
rules_mlxtend = association_rules(frequent_itemsets, metric="lift", min_threshold=1)
rules_mlxtend.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                             antecedents                           consequents  \
# 0  (BOX OF 6 ASSORTED COLOUR TEASPOONS)       (ASSORTED COLOUR BIRD ORNAMENT)
# 1       (ASSORTED COLOUR BIRD ORNAMENT)  (BOX OF 6 ASSORTED COLOUR TEASPOONS)
# 2       (ASSORTED COLOUR BIRD ORNAMENT)      (BOX OF VINTAGE ALPHABET BLOCKS)
# 3      (BOX OF VINTAGE ALPHABET BLOCKS)       (ASSORTED COLOUR BIRD ORNAMENT)
# 4        (BOX OF VINTAGE JIGSAW BLOCKS)       (ASSORTED COLOUR BIRD ORNAMENT)
#
#    antecedent support  consequent support  support  confidence  lift  \
# 0                0.25                0.25     0.25         1.0   4.0
# ...

# %%
rules_mlxtend[ (rules_mlxtend['lift'] >= 4) & (rules_mlxtend['confidence'] >= 0.8) ]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                                  antecedents  \
# 0       (BOX OF 6 ASSORTED COLOUR TEASPOONS)
# 1            (ASSORTED COLOUR BIRD ORNAMENT)
# 2            (ASSORTED COLOUR BIRD ORNAMENT)
# 3           (BOX OF VINTAGE ALPHABET BLOCKS)
# 4             (BOX OF VINTAGE JIGSAW BLOCKS)
# ...                                      ...
# 525181       (ASSORTED COLOUR BIRD ORNAMENT)
# 525182      (BOX OF VINTAGE ALPHABET BLOCKS)
# 525183            (HOME BUILDING BLOCK WORD)
# 525184           (POPPY'S PLAYHOUSE BEDROOM)
# 525185   (FELTCRAFT PRINCESS CHARLOTTE DOLL)
#
# ...
